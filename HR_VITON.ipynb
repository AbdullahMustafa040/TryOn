# %%
# !git clone https://github.com/sangyun884/HR-VITON.git
# Out:
# Cloning into 'HR-VITON'...
# remote: Enumerating objects: 132, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 132 (delta 33), reused 19 (delta 12), pack-reused 74
# Receiving objects: 100% (132/132), 16.06 MiB | 30.28 MiB/s, done.
# Resolving deltas: 100% (67/67), done.

# %%
# %cd ./HR-VITON/
# Out:
# /content/HR-VITON

# %%
# !pip install opencv-python torchgeometry Pillow tqdm tensorboardX scikit-image scipy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 kB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 7.1 MB/s eta 0:00:00
# ...

# %%
# !wget https://uc21263cc849de8b1e3f10efd222.dl.dropboxusercontent.com/cd/0/get/B9XBxfR62kQgDHGwkwuBStLwvjTlACnVw-DOFRRLRqAA0oBSSbEQBlV-CqjyHwYX89Qha_-A9bBgMn-VbZe6XLDP1qda9b0OsidIjWUCONk7q3YDuaDp65hnI4VWSRSFV-gylYQ6l8FCPsvOxNiKwAalCCMrB0veet5IAgPWpYYvdI6MnnhQv8LWX3EiXvphTxc/file?_download_id=67944933875289023557455046779352122925509513548413359484758306259&_notify_domain=www.dropbox.com&dl=1
# Out:
# --2023-06-05 12:09:01--  https://uc21263cc849de8b1e3f10efd222.dl.dropboxusercontent.com/cd/0/get/B9XBxfR62kQgDHGwkwuBStLwvjTlACnVw-DOFRRLRqAA0oBSSbEQBlV-CqjyHwYX89Qha_-A9bBgMn-VbZe6XLDP1qda9b0OsidIjWUCONk7q3YDuaDp65hnI4VWSRSFV-gylYQ6l8FCPsvOxNiKwAalCCMrB0veet5IAgPWpYYvdI6MnnhQv8LWX3EiXvphTxc/file?_download_id=67944933875289023557455046779352122925509513548413359484758306259
# Resolving uc21263cc849de8b1e3f10efd222.dl.dropboxusercontent.com (uc21263cc849de8b1e3f10efd222.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:6018:15::a27d:30f
# Connecting to uc21263cc849de8b1e3f10efd222.dl.dropboxusercontent.com (uc21263cc849de8b1e3f10efd222.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 410 Gone
# 2023-06-05 12:09:02 ERROR 410: Gone.

# %%
# !gdown 1XJTCdRBOPVgVTmqzhVGFAgMm2NLkw5uQ
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1XJTCdRBOPVgVTmqzhVGFAgMm2NLkw5uQ
# To: /content/HR-VITON/mtviton.pth
# 100% 190M/190M [00:04<00:00, 41.0MB/s]

# %%
# !gdown 1T4V3cyRlY5sHVK7Quh_EJY5dovb5FxGX
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1T4V3cyRlY5sHVK7Quh_EJY5dovb5FxGX
# To: /content/HR-VITON/discriminator_mtviton.pth
# 100% 22.4M/22.4M [00:00<00:00, 109MB/s]

# %%
# !gdown 1T5_YDUhYSSKPC_nZMk2NeC-XXUFoYeNy
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1T5_YDUhYSSKPC_nZMk2NeC-XXUFoYeNy
# To: /content/HR-VITON/gen.pth
# 100% 402M/402M [00:03<00:00, 122MB/s]

# %%
# !gdown 1FF3BBSDIA3uavmAiuMH6YFCv09Lt8jUr
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1FF3BBSDIA3uavmAiuMH6YFCv09Lt8jUr
# To: /content/HR-VITON/alex.pth
# 100% 6.01k/6.01k [00:00<00:00, 24.1MB/s]

# %%
# !gdown 1ZA2C8yMOprwc0TV4hvrt0X-ljZugrClq
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ZA2C8yMOprwc0TV4hvrt0X-ljZugrClq
# To: /content/HR-VITON/test.zip
# 100% 2.69M/2.69M [00:00<00:00, 113MB/s]

# %%
# !unzip /content/HR-VITON/test.zip
# Out:
# Archive:  /content/HR-VITON/test.zip
#    creating: test/
#    creating: test/cloth/
#   inflating: test/cloth/02783_00.jpg
#   inflating: test/cloth/07429_00.jpg
#   inflating: test/cloth/11028_00.jpg
#   inflating: test/cloth/11351_00.jpg
#   inflating: test/cloth/01430_00.jpg
#   inflating: test/cloth/03751_00.jpg
#   inflating: test/cloth/06802_00.jpg
#   inflating: test/cloth/08348_00.jpg
#   inflating: test/cloth/09933_00.jpg
#   inflating: test/cloth/06429_00.jpg
#   inflating: test/cloth/11791_00.jpg
#   inflating: test/cloth/01260_00.jpg
#    creating: test/cloth-mask/
#   inflating: test/cloth-mask/02783_00.jpg
#   inflating: test/cloth-mask/07429_00.jpg
#   inflating: test/cloth-mask/11028_00.jpg
#   inflating: test/cloth-mask/11351_00.jpg
#   inflating: test/cloth-mask/01430_00.jpg
#   inflating: test/cloth-mask/03751_00.jpg
#   inflating: test/cloth-mask/06802_00.jpg
#   inflating: test/cloth-mask/08348_00.jpg
#   inflating: test/cloth-mask/09933_00.jpg
# ...

# %%
# !gdown 1ncEHn_6liOot8sgt3A2DOFJBffvx8tW8
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ncEHn_6liOot8sgt3A2DOFJBffvx8tW8
# To: /content/HR-VITON/test_pairs.txt
# 100% 156/156 [00:00<00:00, 1.10MB/s]

# %%
# !mkdir -p ./eval_models/weights/v0.1/

# %%
# !unzip /content/HR-VITON/test.zip

# %%
# !python3 test_generator.py    --dataroot test --data_list test_pairs.txt

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# !wget "https://uc9a227c551b50a6e03e981ca107.dl.dropboxusercontent.com/cd/0/get/B9U7vgJ88oLQ-7XVL18LBYrDCM-GTaAbHJ7EBevP3XkT6d958Bf-lnghkocUmnc8qjb78d_ZAaehQNbRHlLVV6D-_KyDyYMoEIenS74ePTfYGPeJ391HMaIoBFFo2nXUYkMjj-ORYbvi6r1pSVIgiQNQEIp8vL_7d3g5WXZSxaOk69XTnh8Eaw2a60PR_TpSQ2A/file?_download_id=95658006711882894621694386724163742694693547439354728752425608&_notify_domain=www.dropbox.com&dl=1"
# Out:
# --2023-06-05 12:09:43--  https://uc9a227c551b50a6e03e981ca107.dl.dropboxusercontent.com/cd/0/get/B9U7vgJ88oLQ-7XVL18LBYrDCM-GTaAbHJ7EBevP3XkT6d958Bf-lnghkocUmnc8qjb78d_ZAaehQNbRHlLVV6D-_KyDyYMoEIenS74ePTfYGPeJ391HMaIoBFFo2nXUYkMjj-ORYbvi6r1pSVIgiQNQEIp8vL_7d3g5WXZSxaOk69XTnh8Eaw2a60PR_TpSQ2A/file?_download_id=95658006711882894621694386724163742694693547439354728752425608&_notify_domain=www.dropbox.com&dl=1
# Resolving uc9a227c551b50a6e03e981ca107.dl.dropboxusercontent.com (uc9a227c551b50a6e03e981ca107.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:601b:15::a27d:80f
# Connecting to uc9a227c551b50a6e03e981ca107.dl.dropboxusercontent.com (uc9a227c551b50a6e03e981ca107.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 410 Gone
# 2023-06-05 12:09:43 ERROR 410: Gone.

# %%
# !wget https://www.dropbox.com/s/10bfat0kg4si1bu/zalando-hd-resized.zip?dl=0
# Out:
# --2023-06-05 12:09:44--  https://www.dropbox.com/s/10bfat0kg4si1bu/zalando-hd-resized.zip?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:6035:18::a27d:5512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/10bfat0kg4si1bu/zalando-hd-resized.zip [following]
# --2023-06-05 12:09:45--  https://www.dropbox.com/s/raw/10bfat0kg4si1bu/zalando-hd-resized.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc0c51ca1c21f0366669f9d9351e.dl.dropboxusercontent.com/cd/0/inline/B9Yu968Tgzoig8c7b073NnkdZmTptxfoeD2V1oWhdRgLCmEX_-_FKKXXwpVvkwKk5TIwF8KTb7GbUsBsOWIKrpqbbrJ8Iy8e4MVkVnjti1Q0Ake-gc80Ii3yHIu0aHHl8-YvbdwWgLzqaNeHjE1iIWOpqY1x6yRah31NuAQ0oMuy6g/file# [following]
# ...

# %%
# !ls
# Out:
#  alex.pth		     Preprocessing.md
#  cp_dataset.py		     README.md
#  cp_dataset_test.py	     sync_batchnorm
#  discriminator_mtviton.pth   test
#  eval_models		     test_condition.py
#  evaluate.py		     test_generator.py
#  figures		     test_pairs.txt
#  gen.pth		     test.zip
#  get_norm_const.py	     train_condition.py
#  get_parse_agnostic.py	     train_generator.py
#  mtviton.pth		     utils.py
#  network_generator.py	    'zalando-hd-resized.zip?dl=0'
#  networks.py

# %%
# !unzip zalando-hd-resized.zip

# %%
# !python3 test_generator.py --occlusion --test_name {test_name}  --gpu_ids {gpu_ids}  --datasetting unpaired --dataroot test --data_list test_pairs.txt
# Out:
# Namespace(gpu_ids='{gpu_ids}', workers=4, batch_size=1, fp16=False, cuda=False, test_name='{test_name}', dataroot='test', datamode='test', data_list='test_pairs.txt', output_dir='./Output', datasetting='unpaired', fine_width=768, fine_height=1024, tensorboard_dir='./data/zalando-hd-resize/tensorboard', checkpoint_dir='checkpoints', tocg_checkpoint='./eval_models/weights/v0.1/mtviton.pth', gen_checkpoint='./eval_models/weights/v0.1/gen.pth', tensorboard_count=100, shuffle=False, semantic_nc=13, output_nc=13, gen_semantic_nc=7, warp_feature='T1', out_layer='relu', clothmask_composition='warp_grad', upsample='bilinear', occlusion=True, norm_G='spectralaliasinstance', ngf=64, init_type='xavier', init_variance=0.02, num_upsampling_layers='most')
# Start to test %s!
# ...

# %%
# !ls
# Out:
#  alex.pth		     Preprocessing.md
#  cp_dataset.py		     __pycache__
#  cp_dataset_test.py	     README.md
#  discriminator_mtviton.pth   sync_batchnorm
#  eval_models		     test
#  evaluate.py		     test_condition.py
#  figures		     test_generator.py
#  get_norm_const.py	     test_pairs.txt
#  get_parse_agnostic.py	     test.zip
#  network_generator.py	     train_condition.py
#  networks.py		     train_generator.py
#  output			     utils.py
#  Output			    'zalando-hd-resized.zip?dl=0'

# %%
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
import cv2

img = "/content/HR-VITON/test/test/image/12562_00.jpg"
img = cv2.imread(img) # reads image
plt.imshow(img)
